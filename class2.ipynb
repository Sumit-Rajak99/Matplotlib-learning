# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.13.2

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex                 str
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked            str
# class          category
# who                 str
# adult_male         bool
# deck           category
# embark_town         str
# alive               str
# alone              bool
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# np.int64(869)

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.size
# Out:
# 13365

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (784, 15)

# %%
df.age.isnull().sum()
# Out:
# np.int64(106)

# %%
df.age.dropna(inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 784, dtype: float64

# %%
# df.dropna(subset='age',inplace=True)
# df.age.isnull().sum()

# %%
df.dropna(subset='embarked',inplace=True)
df.embarked.isnull().sum()
# Out:
# np.int64(0)

# %%
# embark_town
df.dropna(subset='embark_town',inplace=True)
df.embark_town.isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (782, 15)

# %%
# df.dropna(subset='deck',inplace=True)

# df.deck.isnull().sum()

# %%
df.shape
# Out:
# (782, 15)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
df['age']=df['age'].fillna(df['age'].mean())

# %%
df.deck.unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, str): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df['deck']=df['deck'].cat.add_categories("unknown")
df['deck']=df['deck'].fillna('unknown')

# %%
df.shape
# Out:
# (782, 15)

# %% [markdown]
# ### Q= find the survival rate by age group

# %%
# age_bins=np.arange(0,85,5)
# df['age_group']=pd.cut(df['age'],bins=age_bins)
# surv_by_age=df.groupby('age_group',observed=True)['survived'].mean()
# midpoints=[interval.mid for interval in surv_by_age.index]

# %%
df['age_group']=pd.cut(df['age'],bins=range(0,85,10))
surv_by_age=df.groupby('age_group')['survived'].mean()
plt.figure(figsize=(5,5))
surv_by_age.plot(kind='line',marker='o',figsize=(5,5))
plt.title('survival rate by age')
plt.xlabel('age')
plt.ylabel('survived')
plt.show()

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 885         0       3  female  39.000000      0      5  29.1250        Q
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.809793      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#      class    who  adult_male     deck  embark_town alive  alone age_group
# ...

# %%
plt.figure()
plt.scatter(df['age'],df['fare'])
plt.title('distributions of age fare')
plt.xlabel('age')
plt.ylabel('fare')

plt.show()

# %%
fig,ax=plt.subplots(figsize=(8,4))
sc=ax.scatter(df['age'],df['fare'],c=df['survived'],cmap='coolwarm')

ax.set_title('scatter plot ----- age vs fire')
ax.set_xlabel('age')
ax.set_ylabel('fare(doller)')
cbar=fig.colorbar(sc,ax=ax,ticks=[0,1])
cbar.ax.set_yticklabels(['Died','survived'])
plt.show()

# %%
plt.subplots(figsize=(8,4))
sc=plt.scatter(df['age'],df['fare'],c=df['survived'],cmap='coolwarm')

plt.title('scatter plot ----- age vs fire')
plt.xlabel('age')
plt.ylabel('fare(doller)')
cbar=plt.colorbar(sc)
cbar.set_ticks([1,0])
cbar.set_ticklabels(['Died','Survived'])

plt.show()

# %% [markdown]
# ### Q. draw a bar plot to show the count according to class

# %%
sc=df['class'].value_counts()
sc
# Out:
# class
# Third     405
# First     212
# Second    165
# Name: count, dtype: int64

# %%
sc=df['class'].value_counts()
plt.figure()
c=plt.bar(sc.index,sc.values)
plt.title('count accourding to class')
plt.xlabel('class')
plt.ylabel('count')
plt.bar_label(c)
plt.show()

# %% [markdown]
# ### Q draw a horzontel bar plot show the count according to empbark-town

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: count, dtype: int64

# %%
sc=df['embark_town'].value_counts()
plt.figure()
c=plt.barh(sc.index,sc.values)
plt.title('count accourding to class')
plt.xlabel('count')
plt.ylabel('embark_town')
plt.bar_label(c)
plt.show()

# %% [markdown]
# ### Q. draw a plot to show survival rate according to gender & plot to show count of male & female deathes

# %%
df['sex'].value_counts()
# Out:
# sex
# male      491
# female    291
# Name: count, dtype: int64

# %%
sc=df['sex'].value_counts()
plt.figure()
c=plt.bar(sc.index,sc.values)
plt.title('count accourding to class')
plt.xlabel('count')
plt.ylabel('sex')
plt.bar_label(c)
plt.show()

# %%
grp=df.groupby(['class','sex'])['survived'].mean().unstack()
x=np.arange(len(grp.index))
w=0.35

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.bar(x-w/2,grp['male'],w,label='Male')
plt.bar(x+w/2,grp['female'],w,label='Female')
plt.xticks(x,grp.index)
plt.title("survived rate")
plt.legend()

stack=df.groupby(['class','survived']).size().unstack()
plt.subplot(1,2,2)
plt.bar(stack.index,stack[0],label='Died')
plt.bar(stack.index,stack[1],bottom=stack[0],label='survived')
plt.title("outcome counts")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q what is age count of passenger

# %%
age=df.age.value_counts()
age
# Out:
# age
# 29.809793    106
# 24.000000     29
# 18.000000     25
# 22.000000     24
# 19.000000     23
#             ...
# 24.500000      1
# 0.670000       1
# 0.420000       1
# 34.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
# age=df.age.value_counts()
# plt.figure(figsize=(10,4))
# c=plt.bar(age.index,age.values)
# plt.title('count accourding to age')
# plt.xlabel('age')
# plt.ylabel('count')
# plt.bar_label(c)
# plt.show()

# %%
# df.groupby('count').agg({'age':'count'})
# age
# Out:
# np.float64(23311.25804733728)

# %%
plt.figure(figsize=(5,4))
plt.hist(df['age'],bins=25)
plt.title('count accourding to age')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.show()

# %%
counts=df['class'].value_counts()
plt.figure(figsize=(4,4))
plt.pie(counts,labels=counts.index,autopct='"%1.1f%%',startangle=90)

plt.title("passenger by class")
plt.show()

# %%
coutns,bins=np.histogram(df['age'],bins=25)
plt.figure(figsize=(5,4))
plt.stairs(coutns,bins,fill=True)
plt.title('age distributions')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.savefig('firts_plot')

plt.show()

# %%
plt.savefig('firts_plot')

# %%
fig,ax=plt.subplots(2,2,figsize=(8,8))
ax[0,0].hist(df['age'],bins=20,color='skyblue')
ax[0,0].set_title('age Distribution')

ax[0,1].hist(df['fare'],bins=20,color='orange')
ax[0,1].set_title("fare distribution")

class_counts=df['class'].value_counts()
ax[1,0].bar(class_counts.index,class_counts.values,color="green")
ax[1,0].set_title("passenger by class")

survival=df.groupby('sex')['survived'].mean()
ax[1,1].bar(survival.index,survival.values,color="pink")
ax[1,1].set_title("survival rate by gender")

plt.suptitle("Titnic dashboard")
plt.tight_layout()
plt.show()

# %%
cols=['survived','pclass','age','sibsp','parch','fare']

corr=df[cols].corr()
plt.figure(figsize=(5,4))
sns.heatmap(corr,annot=True,cmap='coolwarm',vmin=-1,vmax=1)
plt.title('feature correction map')
plt.show()
